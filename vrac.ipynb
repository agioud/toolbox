# %% [markdown]
# # exploration data set
#
# pip install ydata-profiling

# %%
from ydata_profiling import ProfileReport 

# génère le Rapport 
profile = ProfileReport(df, title="titre")

# exporter le rapport en HTLM 
profile.to_file("tire.htlm")
